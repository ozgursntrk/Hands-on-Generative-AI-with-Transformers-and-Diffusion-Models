# %%
# !pip install genaibook
# Out:
# Requirement already satisfied: genaibook in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (0.1.1)
# Requirement already satisfied: accelerate in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (1.13.0)
# Requirement already satisfied: sentencepiece in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.2.1)
# Requirement already satisfied: fastcore in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (1.13.6)
# Requirement already satisfied: pandas in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (2.3.3)
# Requirement already satisfied: torch in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (2.11.0+cu128)
# Requirement already satisfied: torchvision in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.26.0+cu128)
# Requirement already satisfied: torchaudio in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (2.11.0+cu128)
# Requirement already satisfied: torchsummary in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (1.5.1)
# Requirement already satisfied: pillow in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (3.10.8)
# Requirement already satisfied: numpy in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (2.2.6)
# Requirement already satisfied: scipy in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (1.15.3)
# Requirement already satisfied: librosa in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.11.0)
# Requirement already satisfied: diffusers in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.38.0)
# Requirement already satisfied: transformers in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (5.12.1)
# Requirement already satisfied: sentence-transformers in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (5.6.0)
# Requirement already satisfied: bitsandbytes in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.49.2)
# Requirement already satisfied: datasets[audio] in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (2.19.0)
# Requirement already satisfied: jiwer in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (4.0.0)
# Requirement already satisfied: evaluate in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.4.6)
# Requirement already satisfied: pydub in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.25.1)
# Requirement already satisfied: compel in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (2.4.0)
# Requirement already satisfied: mediapipe in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.10.35)
# Requirement already satisfied: controlnet-aux in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.0.10)
# Requirement already satisfied: peft in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from genaibook) (0.19.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from accelerate->genaibook) (26.0)
# Requirement already satisfied: psutil in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from accelerate->genaibook) (7.0.0)
# Requirement already satisfied: pyyaml in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from accelerate->genaibook) (6.0.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from accelerate->genaibook) (1.20.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from accelerate->genaibook) (0.8.0rc1)
# Requirement already satisfied: click>=8.4.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (2023.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (0.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from huggingface_hub>=0.21.0->accelerate->genaibook) (4.15.0)
# Requirement already satisfied: anyio in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->genaibook) (4.12.1)
# Requirement already satisfied: certifi in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->genaibook) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->genaibook) (1.0.9)
# Requirement already satisfied: idna in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->genaibook) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->genaibook) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate->genaibook) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate->genaibook) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate->genaibook) (0.0.4)
# Requirement already satisfied: colorama in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from click>=8.4.0->huggingface_hub>=0.21.0->accelerate->genaibook) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate->genaibook) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate->genaibook) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub>=0.21.0->accelerate->genaibook) (0.1.2)
# Requirement already satisfied: setuptools<82 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from torch->genaibook) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from torch->genaibook) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from torch->genaibook) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from torch->genaibook) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from sympy>=1.13.3->torch->genaibook) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.21.0->accelerate->genaibook) (1.3.0)
# Requirement already satisfied: notebook>=6.5.7 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from compel->genaibook) (7.5.5)
# Requirement already satisfied: pyparsing~=3.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from compel->genaibook) (3.3.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from transformers->genaibook) (2026.5.9)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from transformers->genaibook) (0.22.2)
# Requirement already satisfied: importlib_metadata in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from diffusers->genaibook) (9.0.0)
# Requirement already satisfied: requests in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from diffusers->genaibook) (2.33.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from notebook>=6.5.7->compel->genaibook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from notebook>=6.5.7->compel->genaibook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.6,>=4.5.6 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from notebook>=6.5.7->compel->genaibook) (4.5.6)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from notebook>=6.5.7->compel->genaibook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from notebook>=6.5.7->compel->genaibook) (6.5.5)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (3.0.2)
# Requirement already satisfied: pyzmq>=24 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (2.0.5)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (7.2.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (2.3.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (2.4.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.5.7->compel->genaibook) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.5.7->compel->genaibook) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook>=6.5.7->compel->genaibook) (4.25.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (8.30.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (1.6.0)
# Requirement already satisfied: decorator in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (3.0.52)
# Requirement already satisfied: stack-data in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jinja2->torch->genaibook) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.7->compel->genaibook) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.7->compel->genaibook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.7->compel->genaibook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook>=6.5.7->compel->genaibook) (0.28.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (4.9.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (4.0.0)
# Requirement already satisfied: rfc3339-validator in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (2.21.2)
# Requirement already satisfied: six>=1.5 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from requests->diffusers->genaibook) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from requests->diffusers->genaibook) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (2.5)
# Requirement already satisfied: opencv-python-headless in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from controlnet-aux->genaibook) (4.13.0.92)
# Requirement already satisfied: einops in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from controlnet-aux->genaibook) (0.8.2)
# Requirement already satisfied: timm in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from controlnet-aux->genaibook) (1.0.27)
# Requirement already satisfied: scikit-image in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from controlnet-aux->genaibook) (0.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from datasets[audio]->genaibook) (24.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from datasets[audio]->genaibook) (0.7)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from datasets[audio]->genaibook) (0.3.7)
# Requirement already satisfied: xxhash in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from datasets[audio]->genaibook) (3.7.0)
# Requirement already satisfied: multiprocess in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from datasets[audio]->genaibook) (0.70.15)
# Requirement already satisfied: aiohttp in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from datasets[audio]->genaibook) (3.13.5)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from datasets[audio]->genaibook) (0.14.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from aiohttp->datasets[audio]->genaibook) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from aiohttp->datasets[audio]->genaibook) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from aiohttp->datasets[audio]->genaibook) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from aiohttp->datasets[audio]->genaibook) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from aiohttp->datasets[audio]->genaibook) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from aiohttp->datasets[audio]->genaibook) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from aiohttp->datasets[audio]->genaibook) (1.24.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from importlib_metadata->diffusers->genaibook) (4.1.0)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook>=6.5.7->compel->genaibook) (2026.2)
# Requirement already satisfied: rapidfuzz>=3.9.7 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from jiwer->genaibook) (3.14.5)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (0.65.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (1.7.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (1.5.3)
# Requirement already satisfied: pooch>=1.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (1.1.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (0.5)
# Requirement already satisfied: msgpack>=1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from librosa->genaibook) (1.2.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from numba>=0.51.0->librosa->genaibook) (0.47.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from scikit-learn>=1.1.0->librosa->genaibook) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from matplotlib->genaibook) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from matplotlib->genaibook) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from matplotlib->genaibook) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from matplotlib->genaibook) (1.5.0)
# Requirement already satisfied: absl-py~=2.3 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from mediapipe->genaibook) (2.4.0)
# Requirement already satisfied: sounddevice~=0.5 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from mediapipe->genaibook) (0.5.5)
# Requirement already satisfied: flatbuffers~=25.9 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from mediapipe->genaibook) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from mediapipe->genaibook) (4.13.0.92)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from pandas->genaibook) (2026.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from scikit-image->controlnet-aux->genaibook) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from scikit-image->controlnet-aux->genaibook) (2025.5.10)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (3.0.1)
# Requirement already satisfied: pure_eval in c:\users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.6->notebook>=6.5.7->compel->genaibook) (0.2.3)

# %%
from genaibook.core import get_device

# %%
device = get_device()
print(f"Using device {device}")
# Out:
# Using device cuda

# %%
import torch
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    "stable-diffusion-v1-5/stable-diffusion-v1-5",
    torch_dtype = torch.float16,
    variant = "fp16"
).to(device)
# Out:
# W0622 21:43:20.400000 3796 site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# A matching Triton is not available, some optimizations will not be enabled
# Traceback (most recent call last):
#   File "C:\Users\ozgur\anaconda3\envs\dl_ortam\lib\site-packages\xformers\__init__.py", line 57, in _is_triton_available
#     import triton  # noqa
# ModuleNotFoundError: No module named 'triton'
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]

# %%
prompt = "a photograph of an astronaut riding a horse"
pipe(prompt).images[0]
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from transformers import pipeline

# %%
classifier = pipeline("text-classification",device=device)
classifier("This movie is disgustingly good")
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9998304843902588}]

# %%
from transformers import set_seed

set_seed(10)

generator = pipeline("text-generation",device=device)
prompt = "It was dark and stormy"
generator(prompt)[0]["generated_text"]
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.9k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.4k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/5.60k [00:00<?, ?B/s]
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# "It was dark and stormy, and I didn't feel well, and the car broke down in the middle of nowhere. That's my excuse for a bad movie.\n\nI had high hopes for this movie. I had seen some of the cast in other movies, and was looking forward to seeing some of them again. But this movie failed to live up to my expectations.\n\nThe plot was very thin and predictable. The characters were one dimensional. The acting was amateurish. The story was full of plot holes. The directing was average at best.\n\nI think the movie was trying to be an action movie, but it didn't quite succeed. There were some suspenseful moments, but most of the time it just felt like a bad action movie.\n\nThe movie is not worth watching. It is better to watch a bad action movie than this one.\n\nIf you want to see a good action movie, I would recommend something like Die Hard or The Fast and the Furious.\n\nI'm giving this movie a rating of 2 out of 10.\n\nI think the movie could have been a lot better if the writers had done more research on the subject. They could have made the characters more interesting and the plot more complex.\n\nI don't know what happened to the original script. It was probably rewritten and rewritten,"
